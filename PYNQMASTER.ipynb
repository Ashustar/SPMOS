# %% [markdown]
# # SMART POWER MONITERING SYSTEM

# %% [markdown]
# In Our Project XILINX PYNQ Z2 is used as a Main Processing Unit also used as a database which Stores Data and applies Machine Learning Algorithm for Early Prediction of Errors in the Power Grid Prior to the fault. It maintains Grid Database and Sends Reports to the Authority periodically. This Report is composed of Grid Condition,Transformer Health,life Expectency,Voltage and Current readings,faulty Pole Tracking data,short circuit detection,Power Theft info,Transformer switching.

# %% [markdown]
# Features of Pynq Z2 board in out project:
# >.Data base  (_Stores all Data Related to the Grid_)
#
# >.Early Fault Prediction   (_It predicts the Error in the grid Prior to the fault to occue _)
#
#
# >.Grid Network Report
#
# >.Hardware Interface
#
# >.Problem Classification
#
# >.Seasonal Grid Health Prediction
#
# >.Anti Power Theft
# >

# %%
from pynq.overlays.base import BaseOverlay
base = BaseOverlay('base.bit')

# %% [markdown]
# Importing Necessary PYNQ Overlays.

# %%
from pynq.lib.arduino import arduino_io
import time
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
from csv import reader
from sys import exit
from math import sqrt
from operator import itemgetter
import csv
from csv import reader
from sys import exit
from math import sqrt
from operator import itemgetter
import pytz
import random
from datetime import datetime
from dateutil.tz import *

# %% [markdown]
# Importing Necessary libraries.

# %%
led = arduino_io.Arduino_IO(base.ARDUINO, 13, 'out')
d1=arduino_io.Arduino_IO(base.ARDUINO,2,'in')
d2=arduino_io.Arduino_IO(base.ARDUINO,3,'in')
f=arduino_io.Arduino_IO(base.ARDUINO,4,'in')
sc=arduino_io.Arduino_IO(base.ARDUINO,5,'in')
mail=arduino_io.Arduino_IO(base.ARDUINO,6,'in')
flag=0
season=0
month=0
load=0
health='_'
problem_time='_'

# %% [markdown]
# In the above lines, We are Configuring Arduino I/O ports

# %%
breakdowns=0
def gettime():
    now = datetime.now()
    # assuming now contains a timezone aware datetime
    zone = pytz.timezone('Asia/Kolkata')
    TIME_now = now.astimezone(zone)
    #print('time =',(TIME_now).time())
    #print('date =',(TIME_now).date())#datetime.datetime.now().date()
    nela=(TIME_now).date().month
    #print('month =',nela)
    return TIME_now
def predictmonth():
    maheen=(gettime().month)
    if(maheen in range(3,6)):
        seas=3 #summer
    elif(maheen in range(7,10)):
        seas=2 #rainy
    else:
        seas=1 #winter
    return seas 
def seasons():
    season=predictmonth()
    #print(season)
    return season
def temperature():
    if(season in range(1,2)):
        temp=random.randint(50,100)
        #print(temp)
        return temp 
    else:
        temp=random.randint(75,130)
        #print(temp)
        return temp  
def outload():
    if(season in range(1,2)):
        load=random.randint(10,70)
        #print(load)
        return load
    else:
        load=random.randint(40,120)
        #print(load)
        return load    
def fusedowns():    
    if(f.read()==1):    
        #breakdowns=breakdowns+1 
        return 1 
    else:
        return 0
        
def pole():
    p1=d1.read()
    #print('p1=',p1)
    p2=d2.read()
    #print('p2=',p2)
    polenumber=p1*2+p2*1
    if(polenumber>=1):
        problem_time=gettime()
    return polenumber
def addtestdata():
    with open('powertest.csv', mode='w') as employee_file:
        employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        print('season=',seasons())
        employee_writer.writerow([seasons(),temperature(),outload(),fusedowns()])
def email():
    email_user = 'mahesh.muppasani007@gmail.com'
    email_password = 'mahesh@007'
    email_send = 'mohammedkaleemulashwaq@gmail.com'
    subject = 'project report from PYNQ test'
    msg = MIMEMultipart()
    msg['From'] = email_user
    msg['To'] = email_send
    msg['Subject'] = subject
    body = 'Hi there, sending this email from Python!'
    msg.attach(MIMEText(body,'plain'))
    filename='smartpower_report.txt'
    attachment  =open(filename,'rb')
    part = MIMEBase('application','octet-stream')
    part.set_payload((attachment).read())
    encoders.encode_base64(part)
    part.add_header('Content-Disposition',"attachment; filename= "+filename)
    msg.attach(part)
    text = msg.as_string()
    server = smtplib.SMTP('smtp.gmail.com',587)
    server.starttls()
    server.login(email_user,email_password)
    server.sendmail(email_user,email_send,text)
    print('mail sent')
    server.quit()

# %% [markdown]
# Declaring Helper Functions.

# %%
def load_data_set(filename):
    try:
        with open(filename, newline='') as iris:
            return list(reader(iris, delimiter=','))
    except FileNotFoundError as e:
        raise e


def convert_to_float(data_set, mode):
    new_set = []
    try:
        if mode == 'training':
            for data in data_set:
                new_set.append([int(x) for x in data[:len(data)-1]] + [data[len(data)-1]])

        elif mode == 'test':
            for data in data_set:
                new_set.append([int(x) for x in data])

        else:
            print('Invalid mode, program will exit.')
            exit()

        return new_set

    except ValueError as v:
        print(v)
        print('Invalid data set format, program will exit.')
        exit()


def get_classes(training_set):
    return list(set([c[-1] for c in training_set]))


def find_neighbors(distances, k):
    return distances[0:k]


def find_response(neighbors, classes):
    votes = [0] * len(classes)

    for instance in neighbors:
        for ctr, c in enumerate(classes):
            if instance[-2] == c:
                votes[ctr] += 1

    return max(enumerate(votes), key=itemgetter(1))


def knn(training_set, test_set, k):
    distances = []
    dist = 0
    limit = len(training_set[0]) - 1

    # generate response classes from training data
    classes = get_classes(training_set)

    try:
        for test_instance in test_set:
            for row in training_set:
                for x, y in zip(row[:limit], test_instance):
                    dist += (x-y) * (x-y)
                distances.append(row + [sqrt(dist)])
                dist = 0

            distances.sort(key=itemgetter(len(distances[0])-1))

            # find k nearest neighbors
            neighbors = find_neighbors(distances, k)

            # get the class with maximum votes
            index, value = find_response(neighbors, classes)
            outputclass=classes[index]
            # Display prediction
            print('The predicted class for sample ' + str(test_instance) + ' is : ' + classes[index])
            print('Number of votes : ' + str(value) + ' out of ' + str(k))
            # empty the distance list
            distances.clear()
            

    except Exception as e:
        print(e)
    finally:
        return outputclass

# %% [markdown]
# Above Algorithm is used for Electric grid health prediction.

# %%
def ML():
    try:
        # get value of k
        k = 5 #int(input('Enter the value of k : '))
        # load the training and test data set
        training_file ='powerdataset.csv' #input('Enter name of training data file : ')
        test_file = 'powertest.csv'#input('Enter name of test data file : ')
        training_set = convert_to_float(load_data_set(training_file), 'training')
        test_set = convert_to_float(load_data_set(test_file), 'test')

        if not training_set:
            print('Empty training set')

        elif not test_set:
            print('Empty test set')

        elif k > len(training_set):
            print('Expected number of neighbors is higher than number of training data instances')

        else:
            health=knn(training_set, test_set, k)

    except ValueError as v:
        print(v)

    except FileNotFoundError:
        print('File not found')
    finally:
        return health

# %% [markdown]
# Invoking the grid health prediction algorithm in the code.

# %%
def texttomail(swasth):
    file1 = open("smartpower_report.txt","w") 
    #load=130
    health=swasth
    if(health=='normal'):
        life=random.randint(10,20)
    elif(health=='good'):
        life=random.randint(20,30)
    else:
        life=random.randint(3,10)
    if(pole()>=1):
        mypole=pole()
        problem_time=gettime()
        print('problem at pole happened at \n')
        print(problem_time)
    else:
        mypole=0
        problem_time='_'
    
    L = [" ---------------------------------------------------------\n",
        "|     SMART POWER MONITORING powered by SPMOS             |\n ",
         "---------------------------------------------------------\n",
         "|Transformer 1","\n","|AREA : ponnur Line no 21, Street 52\n",
         "|Power UNITS :",str(outload()),"\n",
         "|Health of Transformer:",str(health),"\n",
         "|Life Expectency :",str(life),"\n",
         "|Future Faults :",str('no error'),"\n",
         "|Grid Condition :",str(health),"\n",
         "|Short circuits :",str(fusedowns()),"\n",
         "|Problem at Pole :",str(mypole),"at time :",str(problem_time),"\n",#type pole data and time
         "|Power Theft :",str(fusedowns()),"\n",
        ]  
    print('problematic pole =',pole())
    # \n is placed to indicate EOL (End of Line) 
    file1.write("Hello \n") 
    file1.writelines(L) 
    file1.close() #to change file access modes

# %% [markdown]
# A prompt mail will be sent to Power management Regarding the Grid reports periodically.

# %%
def loop():
    while(1):
        addtestdata() # reads testdata
        time.sleep(1)
        swasth=ML()           #predict test data
        time.sleep(1)
        texttomail(swasth)  #generates a text document to be sent by mail
        time.sleep(1)
        if mail.read()==1:  #if mail summons
            email()  #sending mail to admin
        time.sleep(5)

# %% [markdown]
# Continuosly monitoring the above factors inside this loop.

# %%
def main():
    loop()

if __name__ == '__main__':
    main()
# Out:
# season= 1
# The predicted class for sample [1, 113, 83, 0] is : bad
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 103, 50, 0] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 76, 77, 0] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 103, 56, 0] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 81, 61, 0] is : good
# Number of votes : 2 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 101, 105, 0] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 88, 88, 0] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 100, 84, 0] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 117, 72, 0] is : bad
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 122, 52, 0] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 119, 107, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 86, 76, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 129, 57, 1] is : normal
# Number of votes : 2 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 86, 78, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 108, 64, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 120, 95, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 81, 53, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 78, 77, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 81, 48, 1] is : good
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 123, 47, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 79, 57, 1] is : good
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 102, 47, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 115, 41, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 116, 102, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 119, 57, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 115, 99, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 110, 100, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 95, 97, 1] is : bad
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 83, 82, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 82, 103, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 93, 112, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 113, 40, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 116, 49, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 95, 100, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 94, 113, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 124, 66, 1] is : normal
# Number of votes : 2 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 87, 67, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 126, 41, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 82, 96, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 96, 88, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 116, 47, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 82, 88, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 79, 70, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 106, 91, 1] is : bad
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 84, 57, 1] is : good
# Number of votes : 2 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 98, 58, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 111, 59, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 93, 57, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 102, 41, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 127, 43, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 98, 109, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 122, 103, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 76, 105, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 123, 57, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 94, 42, 1] is : good
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 96, 69, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 85, 47, 1] is : good
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 117, 99, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 119, 113, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 122, 48, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 82, 67, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 124, 47, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 105, 115, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 86, 75, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 117, 87, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 77, 96, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 119, 52, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 76, 91, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 79, 43, 1] is : good
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 87, 55, 1] is : good
# Number of votes : 2 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 126, 111, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 109, 61, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 94, 88, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 100, 76, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 112, 55, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 94, 46, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 116, 81, 1] is : bad
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 128, 58, 1] is : normal
# Number of votes : 2 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 75, 41, 1] is : good
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 81, 73, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 114, 89, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 119, 47, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 124, 76, 1] is : bad
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 91, 76, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 130, 42, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 102, 67, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 96, 73, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 128, 98, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 92, 88, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 93, 83, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 115, 42, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 99, 55, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 98, 73, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 120, 97, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 86, 91, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 88, 108, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 99, 112, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 88, 91, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 105, 52, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 96, 101, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 92, 87, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 118, 56, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 103, 89, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 110, 69, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 102, 93, 1] is : bad
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 128, 84, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 91, 45, 1] is : good
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 122, 87, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 77, 49, 1] is : good
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 109, 96, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 123, 52, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 80, 48, 1] is : good
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 83, 92, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 109, 116, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 81, 49, 1] is : good
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 102, 87, 1] is : normal
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 89, 114, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 129, 73, 1] is : bad
# Number of votes : 3 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 106, 106, 1] is : bad
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 78, 82, 1] is : normal
# Number of votes : 5 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 99, 78, 1] is : normal
# Number of votes : 4 out of 5
# problematic pole = 0
# season= 1
# The predicted class for sample [1, 109, 87, 1] is : bad
# Number of votes : 4 out of 5
# problematic pole = 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-176-babb4cfe777f> in <module>()
#       3
#       4 if __name__ == '__main__':
# ----> 5     main()
#
# <ipython-input-176-babb4cfe777f> in main()
#       1 def main():
# ----> 2     loop()
#       3
#       4 if __name__ == '__main__':
#       5     main()
#
# <ipython-input-175-e14ed3879044> in loop()
#       9         if mail.read()==1:  #if mail summons
#      10             email()  #sending mail to admin
# ---> 11         time.sleep(5)
#      12
#      13
#
# KeyboardInterrupt:

# %% [markdown]
# Driver program to run the entire code.
